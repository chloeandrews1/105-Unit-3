# %% [markdown]
# # Procedural Overview
#
# In order to make COVID-19 data more coherent, it is aggregated into data for each providence/state of Mainland China. The .csv files created during this procedure display information about COVID-19 confirmed cases, deaths, and recovered statistics. Python functions such as for loops, concatenation, and other methods from the Pandas software make this data manipulation and analysis possible.
#
# ## To Set Up Data
#
# 1. Connect Google Colab Notebooks to Google Drive by using the drive.mount function (as shown below).
#   - Import each of the datasets as its own object using pandas.
# 2. Import pandas as an object, so that its methods can be used to manipulate the data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Sets
#
# The datasets used in this example were downloaded from [COVID-19 Archived Data ](https://github.com/CSSEGISandData/COVID-19/blob/master/archived_data/archived_daily_case_updates/02-14-2020_1123.csv)

# %%
data=pd.read_csv('gdrive/My Drive/newdata.csv')
data
# Out:
#      Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0             Hubei  Mainland China  2/14/2020 10:03      51986    1318
# 1         Guangdong  Mainland China  2/14/2020 12:53       1261       2
# 2             Henan  Mainland China  2/14/2020 12:53       1184      11
# 3          Zhejiang  Mainland China  2/14/2020 14:13       1155       0
# 4             Hunan  Mainland China   2/14/2020 9:23        988       2
# ..              ...             ...              ...        ...     ...
# 69      Madison, WI              US   2/5/2020 21:53          1       0
# 70       Orange, CA              US   2/1/2020 19:53          1       0
# 71  San Antonio, TX              US  2/13/2020 18:53          1       0
# 72      Seattle, WA              US    2/9/2020 7:03          1       0
# 73        Tempe, AZ              US   2/1/2020 19:43          1       0
#
#     Recovered
# 0        3900
# 1         362
# 2         357
# 3         403
# 4         364
# ..        ...
# 69          0
# 70          0
# 71          0
# 72          1
# 73          0
#
# [74 rows x 6 columns]

# %% [markdown]
# # Original Data Attributes
#
#   - By using the .shape function we are able to configure the total amount of rows and columns (in that order) are in our data set
#   - the .shape function shows how many values are totalled into our data set
#   - .columns provides the column names for the Dataframe
#   - .dtypes provides the pandas datatype for each column

# %%
data.shape
# Out:
# (74, 6)

# %%
data.size
# Out:
# 444

# %%
data.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Last Update', 'Confirmed',
#        'Deaths', 'Recovered'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Province/State    object
# Country/Region    object
# Last Update       object
# Confirmed          int64
# Deaths             int64
# Recovered          int64
# dtype: object

# %% [markdown]
# ## Methods
#
# - We can look at the first 5 or last 5 rows in the dataset directly with the `.head()` and `.tail()` methods.
# - .sample (n=#) gives a random sample from the data set

# %%
data.head()
# Out:
#   Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  2/14/2020 10:03      51986    1318
# 1      Guangdong  Mainland China  2/14/2020 12:53       1261       2
# 2          Henan  Mainland China  2/14/2020 12:53       1184      11
# 3       Zhejiang  Mainland China  2/14/2020 14:13       1155       0
# 4          Hunan  Mainland China   2/14/2020 9:23        988       2
#
#    Recovered
# 0       3900
# 1        362
# 2        357
# 3        403
# 4        364

# %%
data.tail()
# Out:
#      Province/State Country/Region      Last Update  Confirmed  Deaths  \
# 69      Madison, WI             US   2/5/2020 21:53          1       0
# 70       Orange, CA             US   2/1/2020 19:53          1       0
# 71  San Antonio, TX             US  2/13/2020 18:53          1       0
# 72      Seattle, WA             US    2/9/2020 7:03          1       0
# 73        Tempe, AZ             US   2/1/2020 19:43          1       0
#
#     Recovered
# 69          0
# 70          0
# 71          0
# 72          1
# 73          0

# %%
data.sample(n=5)
# Out:
#                   Province/State Country/Region      Last Update  Confirmed  \
# 60                           NaN       Cambodia   2/12/2020 7:43          1
# 71               San Antonio, TX             US  2/13/2020 18:53          1
# 18  Diamond Princess cruise ship         Others   2/14/2020 0:13        218
# 73                     Tempe, AZ             US   2/1/2020 19:43          1
# 47              British Columbia         Canada    2/7/2020 5:43          4
#
#     Deaths  Recovered
# 60       0          1
# 71       0          0
# 18       0          0
# 73       0          0
# 47       0          0

# %% [markdown]
# # Creating a Subset
#
# - We can extract a single column by using bracket notation: df["column_example"]
# -

# %%
data["Confirmed"]
# Out:
# 0     51986
# 1      1261
# 2      1184
# 3      1155
# 4       988
#       ...
# 69        1
# 70        1
# 71        1
# 72        1
# 73        1
# Name: Confirmed, Length: 74, dtype: int64

# %%
print(data.Confirmed.shape)
print(data.Confirmed.dtypes)
# Out:
# (74,)
# int64

# %%
data.Confirmed.value_counts()
# Out:
# Confirmed
# 1        15
# 2         8
# 3         3
# 4         3
# 16        2
# 67        2
# 65        2
# 18        2
# 10        1
# 11        1
# 9         1
# 120       1
# 19        1
# 28        1
# 29        1
# 33        1
# 56        1
# 8         1
# 5         1
# 86        1
# 90        1
# 119       1
# 51986     1
# 1261      1
# 140       1
# 1184      1
# 1155      1
# 988       1
# 934       1
# 900       1
# 593       1
# 532       1
# 523       1
# 463       1
# 419       1
# 372       1
# 318       1
# 283       1
# 281       1
# 230       1
# 226       1
# 218       1
# 162       1
# 159       1
# 126       1
# Name: count, dtype: int64

# %%
data.dtypes.value_counts()
# Out:
# object    3
# int64     3
# Name: count, dtype: int64

# %%
data.Confirmed.value_counts()
# Out:
# Confirmed
# 1        15
# 2         8
# 3         3
# 4         3
# 16        2
# 67        2
# 65        2
# 18        2
# 10        1
# 11        1
# 9         1
# 120       1
# 19        1
# 28        1
# 29        1
# 33        1
# 56        1
# 8         1
# 5         1
# 86        1
# 90        1
# 119       1
# 51986     1
# 1261      1
# 140       1
# 1184      1
# 1155      1
# 988       1
# 934       1
# 900       1
# 593       1
# 532       1
# 523       1
# 463       1
# 419       1
# 372       1
# 318       1
# 283       1
# 281       1
# 230       1
# 226       1
# 218       1
# 162       1
# 159       1
# 126       1
# Name: count, dtype: int64

# %%
data [0:3]
# Out:
#   Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  2/14/2020 10:03      51986    1318
# 1      Guangdong  Mainland China  2/14/2020 12:53       1261       2
# 2          Henan  Mainland China  2/14/2020 12:53       1184      11
#
#    Recovered
# 0       3900
# 1        362
# 2        357

# %%
data["Confirmed"][0:5]
# Out:
# 0    51986
# 1     1261
# 2     1184
# 3     1155
# 4      988
# Name: Confirmed, dtype: int64

# %% [markdown]
# If we use the `.iloc` attribute before our brackets, pandas accepts two numbers separated by a comma. The first number is for rows and the second for columns.
#
#
# - If we still want to use the column names, we can use the .loc attribute instead.

# %%
data.iloc[2, 3]
# Out:
# 1184

# %%
data.iloc[:,3] # All rows of column 3
# Out:
# 0     51986
# 1      1261
# 2      1184
# 3      1155
# 4       988
#       ...
# 69        1
# 70        1
# 71        1
# 72        1
# 73        1
# Name: Confirmed, Length: 74, dtype: int64

# %%
data.iloc[0:3,:] # Rows 0-2 of all columns
# Out:
#   Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  2/14/2020 10:03      51986    1318
# 1      Guangdong  Mainland China  2/14/2020 12:53       1261       2
# 2          Henan  Mainland China  2/14/2020 12:53       1184      11
#
#    Recovered
# 0       3900
# 1        362
# 2        357

# %%
data.iloc[120:126,2:8] # Rows 120-125 of columns 2-8
# Out:
# Empty DataFrame
# Columns: [Last Update, Confirmed, Deaths, Recovered]
# Index: []

# %%
data.loc[0:3,"Confirmed"]
# Out:
# 0    51986
# 1     1261
# 2     1184
# 3     1155
# Name: Confirmed, dtype: int64

# %% [markdown]
# #Subset Compile
#
# - We identified our subset as "subset" to be easily identifiable.
# - after naming, we extracted specficially "Mainland China" from the Country/Region Column to create a filtered subset.

# %%
subset = data[data["Country/Region"] == "Mainland China"]
subset
# Out:
#     Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0            Hubei  Mainland China  2/14/2020 10:03      51986    1318
# 1        Guangdong  Mainland China  2/14/2020 12:53       1261       2
# 2            Henan  Mainland China  2/14/2020 12:53       1184      11
# 3         Zhejiang  Mainland China  2/14/2020 14:13       1155       0
# 4            Hunan  Mainland China   2/14/2020 9:23        988       2
# 5            Anhui  Mainland China  2/14/2020 12:53        934       6
# 6          Jiangxi  Mainland China   2/14/2020 1:13        900       1
# 7          Jiangsu  Mainland China  2/14/2020 10:03        593       0
# 8        Chongqing  Mainland China   2/14/2020 8:53        532       5
# 9         Shandong  Mainland China  2/14/2020 11:13        523       2
# 10         Sichuan  Mainland China  2/14/2020 11:13        463       1
# 11    Heilongjiang  Mainland China  2/14/2020 13:23        419      11
# 12         Beijing  Mainland China   2/14/2020 6:33        372       3
# 13        Shanghai  Mainland China   2/14/2020 4:13        318       1
# 14           Hebei  Mainland China  2/14/2020 11:13        283       3
# 15          Fujian  Mainland China  2/14/2020 11:13        281       0
# 16         Shaanxi  Mainland China  2/14/2020 12:53        230       0
# 17         Guangxi  Mainland China  2/14/2020 15:23        226       2
# 19          Yunnan  Mainland China  2/14/2020 12:53        162       0
# 20          Hainan  Mainland China  2/14/2020 15:23        159       4
# 21         Guizhou  Mainland China   2/14/2020 1:53        140       1
# 22          Shanxi  Mainland China   2/14/2020 6:33        126       0
# 23         Tianjin  Mainland China  2/14/2020 11:13        120       3
# 24        Liaoning  Mainland China  2/14/2020 15:23        119       1
# 25           Gansu  Mainland China  2/13/2020 15:53         90       2
# 26           Jilin  Mainland China   2/14/2020 0:43         86       1
# 27         Ningxia  Mainland China   2/14/2020 1:43         67       0
# 29  Inner Mongolia  Mainland China   2/14/2020 2:03         65       0
# 30        Xinjiang  Mainland China   2/14/2020 1:13         65       1
# 36         Qinghai  Mainland China   2/13/2020 8:43         18       0
# 63           Tibet  Mainland China   2/12/2020 6:43          1       0
#
#     Recovered
# 0        3900
# 1         362
# 2         357
# 3         403
# 4         364
# 5         193
# 6         187
# 7         157
# 8         139
# 9         136
# 10        114
# 11         47
# 12         80
# 13         90
# 14         87
# 15         63
# 16         54
# 17         36
# 19         36
# 20         43
# 21         28
# 22         38
# 23         31
# 24         29
# 25         39
# 26         25
# 27         24
# 29          6
# 30          6
# 36         11
# 63          1

# %%
subset.shape
# Out:
# (31, 6)

# %%
subset.size
# Out:
# 186

# %%
subset.Confirmed.value_counts()
# Out:
# Confirmed
# 65       2
# 51986    1
# 1261     1
# 18       1
# 67       1
# 86       1
# 90       1
# 119      1
# 120      1
# 126      1
# 140      1
# 159      1
# 162      1
# 226      1
# 230      1
# 281      1
# 283      1
# 318      1
# 372      1
# 419      1
# 463      1
# 523      1
# 532      1
# 593      1
# 900      1
# 934      1
# 988      1
# 1155     1
# 1184     1
# 1        1
# Name: count, dtype: int64

# %% [markdown]
# Make the cumulative dataframe into a .csv file using the .to_csv function from the Pandas software

# %%
subset.to_csv("new_subset.csv", index=False)

# %%
new_data=pd.read_csv('new_subset.csv')
new_data
# Out:
#     Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0            Hubei  Mainland China  2/14/2020 10:03      51986    1318
# 1        Guangdong  Mainland China  2/14/2020 12:53       1261       2
# 2            Henan  Mainland China  2/14/2020 12:53       1184      11
# 3         Zhejiang  Mainland China  2/14/2020 14:13       1155       0
# 4            Hunan  Mainland China   2/14/2020 9:23        988       2
# 5            Anhui  Mainland China  2/14/2020 12:53        934       6
# 6          Jiangxi  Mainland China   2/14/2020 1:13        900       1
# 7          Jiangsu  Mainland China  2/14/2020 10:03        593       0
# 8        Chongqing  Mainland China   2/14/2020 8:53        532       5
# 9         Shandong  Mainland China  2/14/2020 11:13        523       2
# 10         Sichuan  Mainland China  2/14/2020 11:13        463       1
# 11    Heilongjiang  Mainland China  2/14/2020 13:23        419      11
# 12         Beijing  Mainland China   2/14/2020 6:33        372       3
# 13        Shanghai  Mainland China   2/14/2020 4:13        318       1
# 14           Hebei  Mainland China  2/14/2020 11:13        283       3
# 15          Fujian  Mainland China  2/14/2020 11:13        281       0
# 16         Shaanxi  Mainland China  2/14/2020 12:53        230       0
# 17         Guangxi  Mainland China  2/14/2020 15:23        226       2
# 18          Yunnan  Mainland China  2/14/2020 12:53        162       0
# 19          Hainan  Mainland China  2/14/2020 15:23        159       4
# 20         Guizhou  Mainland China   2/14/2020 1:53        140       1
# 21          Shanxi  Mainland China   2/14/2020 6:33        126       0
# 22         Tianjin  Mainland China  2/14/2020 11:13        120       3
# 23        Liaoning  Mainland China  2/14/2020 15:23        119       1
# 24           Gansu  Mainland China  2/13/2020 15:53         90       2
# 25           Jilin  Mainland China   2/14/2020 0:43         86       1
# 26         Ningxia  Mainland China   2/14/2020 1:43         67       0
# 27  Inner Mongolia  Mainland China   2/14/2020 2:03         65       0
# 28        Xinjiang  Mainland China   2/14/2020 1:13         65       1
# 29         Qinghai  Mainland China   2/13/2020 8:43         18       0
# 30           Tibet  Mainland China   2/12/2020 6:43          1       0
#
#     Recovered
# 0        3900
# 1         362
# 2         357
# 3         403
# 4         364
# 5         193
# 6         187
# 7         157
# 8         139
# 9         136
# 10        114
# 11         47
# 12         80
# 13         90
# 14         87
# 15         63
# 16         54
# 17         36
# 18         36
# 19         43
# 20         28
# 21         38
# 22         31
# 23         29
# 24         39
# 25         25
# 26         24
# 27          6
# 28          6
# 29         11
# 30          1
